# %%
pip install pyarrow
# Out:
# ...
#    ---------------------------------------- 0.0/25.8 MB ? eta -:--:--
#    - -------------------------------------- 0.8/25.8 MB 8.5 MB/s eta 0:00:03
#    -- ------------------------------------- 1.3/25.8 MB 4.0 MB/s eta 0:00:07
#    --- ------------------------------------ 2.1/25.8 MB 3.6 MB/s eta 0:00:07
#    --- ------------------------------------ 2.1/25.8 MB 3.6 MB/s eta 0:00:07
#    ---- ----------------------------------- 2.6/25.8 MB 2.7 MB/s eta 0:00:09
#    ---- ----------------------------------- 3.1/25.8 MB 2.5 MB/s eta 0:00:10
#    ----- ---------------------------------- 3.7/25.8 MB 2.5 MB/s eta 0:00:10
#    ------ --------------------------------- 3.9/25.8 MB 2.3 MB/s eta 0:00:10
#    ------ --------------------------------- 4.2/25.8 MB 2.1 MB/s eta 0:00:11
#    ------ --------------------------------- 4.2/25.8 MB 2.1 MB/s eta 0:00:11
#    ------ --------------------------------- 4.5/25.8 MB 2.0 MB/s eta 0:00:11
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("alternate_recipient_2.csv")
# Out:
# C:\Users\alvan\AppData\Local\Temp\ipykernel_18284\3667450632.py:1: DtypeWarning: Columns (7,8,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("alternate_recipient_2.csv")

# %%
df.shape
# Out:
# (11481055, 19)

# %%
df.head(2)
# Out:
#    Unnamed: 0        ingest_grant_ID    alt_EIN  \
# 0           0  010019705_2018_2020_1  540545202
# 1           1  010019705_2020_2022_1  540545202
#
#                                             org_name             address  \
# 0  George Washington Masonic National Memorial As...  110 Callahan Drive
# 1  GEO WASHINGTON MASONIC NATIONAL MEMORIAL ASSOC...  110 CALLAHAN DRIVE
#
#          city state    zip   zip5  county_code country  latitude  longitude  \
# 0  Alexandria    VA  22301  22301      51510.0      US       NaN        NaN
# 1  ALEXANDRIA    VA  22301  22301      51510.0      US       NaN        NaN
#
#    amt_grant  grant_date                                      grant_purpose  \
# 0      17940  2019-03-31  To support the George Washington Memorial and ...
# 1      34577  2021-03-31  TO SUPPORT THE GEORGE WASHINGTON MEMORIAL AND ...
#
#   org_source  ntee_estimate last_update_timestamp
# 0        990            NaN   2024-07-27 14:32:52
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ingest_grant_ID', 'alt_EIN', 'org_name', 'address',
#        'city', 'state', 'zip', 'zip5', 'county_code', 'country', 'latitude',
#        'longitude', 'amt_grant', 'grant_date', 'grant_purpose', 'org_source',
#        'ntee_estimate', 'last_update_timestamp'],
#       dtype='object')

# %%
df_new = df[(df["org_source"]=="990pf") & (pd.to_datetime(df["grant_date"], errors='coerce').dt.year==2021)]

# %%
df_new.shape
# Out:
# (1970653, 19)

# %%
df_new.head()
# Out:
#      Unnamed: 0         ingest_grant_ID  alt_EIN  \
# 3             3   010024907_2020_2021_1        0
# 4             4   010024907_2020_2021_2        0
# 35           35   010131950_2021_2022_1        0
# 251         251   010211484_2020_2023_1        0
# 252         252  010211484_2020_2023_10        0
#
#                                 org_name                address  \
# 3          BAR HARBOR HISTORICAL SOCIETY       127 WEST STREERT
# 4                 MDI HISTORICAL SOCIETY  1892 SCHOOLHOUSE ROAD
# 35   Patients of Plant Assisted Living S    1 Washington Street
# 251                   Bangor High School           885 Broadway
# 252                     Tides Foundation           PO Box 29903
#
#               city state    zip   zip5  county_code country  latitude  \
# 3       BAR HARBOR    ME  04609  04609          NaN      US       NaN
# 4     MOUNT DESERT    ME  04660  04660          NaN      US       NaN
# ...

# %%
df_new["zip"] = df_new["zip"].astype(str)

df_new["zip5"] = df_new["zip5"].astype(str)
# Out:
# C:\Users\alvan\AppData\Local\Temp\ipykernel_18284\469303723.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["zip"] = df_new["zip"].astype(str)
# C:\Users\alvan\AppData\Local\Temp\ipykernel_18284\469303723.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["zip5"] = df_new["zip5"].astype(str)

# %%
df_new.to_parquet("990pf_alternate_recipient_2_year_2021.parquet", index=False)

# %%
df_new.to_csv("990pf_alternate_recipient_2_year_2021.csv", index=False)
